# %% [markdown]
# ## Step 1: Data Understanding
#
# In this step, I explore the dataset to understand its structure and content.
# This includes examining the columns, data types, and general information about the data.

# %%
#Load Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('alzheimers_disease_data.csv')

# %%
#Preview Data
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
# 4           18.454356          6.310461     0.795498  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# ...

# %%
#Dataset Structure
df.shape  # (rows, columns)
# Out:
# (2149, 35)

# %%
#List of Columns
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality',
#        'SleepQuality', 'FamilyHistoryAlzheimers', 'CardiovascularDisease',
#        'Diabetes', 'Depression', 'HeadInjury', 'Hypertension', 'SystolicBP',
#        'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment',
#        'MemoryComplaints', 'BehavioralProblems', 'ADL', 'Confusion',
#        'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks',
#        'Forgetfulness', 'Diagnosis', 'DoctorInCharge'],
#       dtype='str')

# %%
#Data Types & Info
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %%
#Statistical Summary
df.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  EducationLevel  \
# count  2149.000000  2149.000000  2149.000000  2149.000000     2149.000000
# mean   5825.000000    74.908795     0.506282     0.697534        1.286645
# std     620.507185     8.990221     0.500077     0.996128        0.904527
# min    4751.000000    60.000000     0.000000     0.000000        0.000000
# 25%    5288.000000    67.000000     0.000000     0.000000        1.000000
# 50%    5825.000000    75.000000     1.000000     0.000000        1.000000
# 75%    6362.000000    83.000000     1.000000     1.000000        2.000000
# max    6899.000000    90.000000     1.000000     3.000000        3.000000
#
#                BMI      Smoking  AlcoholConsumption  PhysicalActivity  \
# count  2149.000000  2149.000000         2149.000000       2149.000000
# mean     27.655697     0.288506           10.039442          4.920202
# std       7.217438     0.453173            5.757910          2.857191
# ...

# %%
#Age analysis
analysis = [min(df['Age']),max(df['Age'])]
print(analysis)
# Out:
# [60, 90]

# %%
#Average Age
import numpy as np
avg = np.mean(df['Age'])
print(avg)
# Out:
# 74.90879478827361

# %%
#Categorical Distribution
df['Gender'].value_counts()
# Out:
# Gender
# 1    1088
# 0    1061
# Name: count, dtype: int64

# %% [markdown]
# ## Step 2: Data Cleaning
#
# In this step, I prepare the dataset for analysis by handling missing values, checking for duplicates, and correcting any inconsistencies in the data.
#
# The goal is to ensure that the data is clean, reliable, and ready for further exploration.

# %%
#Drop useless columns
df = df.drop(columns=['PatientID','DoctorInCharge'])

# %%
#Missing Values Check
df.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Ethnicity                    0
# EducationLevel               0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# CholesterolLDL               0
# CholesterolHDL               0
# CholesterolTriglycerides     0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# Confusion                    0
# Disorientation               0
# PersonalityChanges           0
# ...

# %%
#Duplicate Rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Unique values
df.nunique()
# Out:
# Age                            31
# Gender                          2
# Ethnicity                       4
# EducationLevel                  4
# BMI                          2149
# Smoking                         2
# AlcoholConsumption           2149
# PhysicalActivity             2149
# DietQuality                  2149
# SleepQuality                 2149
# FamilyHistoryAlzheimers         2
# CardiovascularDisease           2
# Diabetes                        2
# Depression                      2
# HeadInjury                      2
# Hypertension                    2
# SystolicBP                     90
# DiastolicBP                    60
# CholesterolTotal             2149
# CholesterolLDL               2149
# CholesterolHDL               2149
# CholesterolTriglycerides     2149
# MMSE                         2149
# FunctionalAssessment         2149
# MemoryComplaints                2
# BehavioralProblems              2
# ADL                          2149
# ...

# %%
#wrong data types
df.dtypes
# Out:
# Age                            int64
# Gender                         int64
# Ethnicity                      int64
# EducationLevel                 int64
# BMI                          float64
# Smoking                        int64
# AlcoholConsumption           float64
# PhysicalActivity             float64
# DietQuality                  float64
# SleepQuality                 float64
# FamilyHistoryAlzheimers        int64
# CardiovascularDisease          int64
# Diabetes                       int64
# Depression                     int64
# HeadInjury                     int64
# Hypertension                   int64
# SystolicBP                     int64
# DiastolicBP                    int64
# CholesterolTotal             float64
# CholesterolLDL               float64
# CholesterolHDL               float64
# CholesterolTriglycerides     float64
# MMSE                         float64
# FunctionalAssessment         float64
# MemoryComplaints               int64
# ...

# %% [markdown]
# Step 3: Data Analysis

# %%
#What is the proportion of patients with Alzheimer's vs without in this dataset?
import matplotlib.pyplot as plt

df['Diagnosis'].value_counts().plot(kind='bar', color=['steelblue', 'salmon'])
plt.title('Alzheimer Distribution')
plt.xticks([0, 1], ['No Alzheimer', 'Alzheimer'], rotation=0)
plt.ylabel('Number of Patients')
plt.show()

# %%
df.head()
# Out:
#    Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0   73       0          0               2  22.927749        0
# 1   89       0          0               0  26.827681        0
# 2   73       0          3               1  17.795882        0
# 3   74       1          0               1  33.800817        1
# 4   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  ...  \
# 0           13.297218          6.327112     1.347214      9.025679  ...
# 1            4.542524          7.619885     0.518767      7.151293  ...
# 2           19.555085          7.844988     1.826335      9.673574  ...
# 3           12.209266          8.428001     7.435604      8.392554  ...
# 4           18.454356          6.310461     0.795498      5.597238  ...
#
#    FunctionalAssessment  MemoryComplaints  BehavioralProblems       ADL  \
# 0              6.518877                 0                   0  1.725883
# ...

# %%
df['Diagnosis'].value_counts()
# Out:
# Diagnosis
# 0    1389
# 1     760
# Name: count, dtype: int64

# %%
df.groupby('Diagnosis')['Age'].mean()
# Out:
# Diagnosis
# 0    74.945284
# 1    74.842105
# Name: Age, dtype: float64

# %%
sns.boxplot(x='Diagnosis', y='Age', data=df)
plt.show()

# %%
pd.crosstab(df['Gender'], df['Diagnosis'], normalize='index')
# Out:
# Diagnosis         0         1
# Gender
# 0          0.636192  0.363808
# 1          0.656250  0.343750

# %%
pd.crosstab(df['EducationLevel'], df['Diagnosis'], normalize='index')
# Out:
# Diagnosis              0         1
# EducationLevel
# 0               0.609865  0.390135
# 1               0.646370  0.353630
# 2               0.658805  0.341195
# 3               0.685446  0.314554

# %%
pd.crosstab(df['Ethnicity'], df['Diagnosis'], normalize='index')
# Out:
# Diagnosis         0         1
# Ethnicity
# 0          0.637715  0.362285
# 1          0.678414  0.321586
# 2          0.592233  0.407767
# 3          0.682464  0.317536

# %%
pd.crosstab(df['Smoking'], df['Diagnosis'], normalize='index')
# Out:
# Diagnosis         0         1
# Smoking
# 0          0.644866  0.355134
# 1          0.650000  0.350000

# %%
df.groupby('Diagnosis')['BMI'].mean()
# Out:
# Diagnosis
# 0    27.515092
# 1    27.912670
# Name: BMI, dtype: float64

# %%
df.groupby('Diagnosis')['AlcoholConsumption'].mean()
# Out:
# Diagnosis
# 0    10.071880
# 1     9.980156
# Name: AlcoholConsumption, dtype: float64

# %%
df.groupby('Diagnosis')['PhysicalActivity'].mean()
# Out:
# Diagnosis
# 0    4.90764
# 1    4.94316
# Name: PhysicalActivity, dtype: float64

# %%
df.groupby('Diagnosis')['DietQuality'].mean()
# Out:
# Diagnosis
# 0    4.974839
# 1    5.026581
# Name: DietQuality, dtype: float64

# %%
df.groupby('Diagnosis')['SleepQuality'].mean()
# Out:
# Diagnosis
# 0    7.124832
# 1    6.916292
# Name: SleepQuality, dtype: float64

# %%
pd.crosstab(df['FamilyHistoryAlzheimers']
            , df['Diagnosis'], normalize='index')
# Out:
# Diagnosis                       0         1
# FamilyHistoryAlzheimers
# 0                        0.637212  0.362788
# 1                        0.673432  0.326568

# %%
pd.crosstab(df['CardiovascularDisease']
            , df['Diagnosis'], normalize='index')
# Out:
# Diagnosis                     0         1
# CardiovascularDisease
# 0                      0.652529  0.347471
# 1                      0.609677  0.390323

# %%
pd.crosstab(df['Diabetes']
            , df['Diagnosis'], normalize='index')
# Out:
# Diagnosis         0         1
# Diabetes
# 0          0.640000  0.360000
# 1          0.682099  0.317901

# %%
pd.crosstab(df['Depression']
            , df['Diagnosis'], normalize='index')
# Out:
# Diagnosis          0         1
# Depression
# 0           0.644936  0.355064
# 1           0.651972  0.348028

# %%
pd.crosstab(df['HeadInjury']
            , df['Diagnosis'], normalize='index')
# Out:
# Diagnosis          0         1
# HeadInjury
# 0           0.643077  0.356923
# 1           0.678392  0.321608

# %%
pd.crosstab(df['Hypertension']
            , df['Diagnosis'], normalize='index')
# Out:
# Diagnosis            0         1
# Hypertension
# 0             0.653362  0.346638
# 1             0.606250  0.393750

# %%
clinical = ['SystolicBP', 'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides']

#f.groupby('Diagnosis')[clinical].mean()
df.groupby('Diagnosis')[clinical].mean().T.plot(kind='bar', color=['steelblue', 'salmon'])
plt.title('Clinical Measurements: Healthy vs Alzheimer')
plt.xticks(rotation=45)
plt.legend(['Healthy', 'Alzheimer'])
plt.tight_layout()
plt.show()

# %%
df.groupby('Diagnosis')[clinical].mean()
# Out:
#            SystolicBP  DiastolicBP  CholesterolTotal  CholesterolLDL  \
# Diagnosis
# 0          134.564435    89.778978        224.996342      125.361434
# 1          133.717105    89.973684        225.565197      122.461726
#
#            CholesterolHDL  CholesterolTriglycerides
# Diagnosis
# 0               58.734832                226.571537
# 1               60.795330                231.406671

# %%
numerical_cog = ['MMSE', 'FunctionalAssessment', 'ADL']
df.groupby('Diagnosis')[numerical_cog].mean()
# Out:
#                 MMSE  FunctionalAssessment       ADL
# Diagnosis
# 0          16.265543              5.860669  5.707951
# 1          11.994657              3.653380  3.657938

# %%
df.groupby('Diagnosis')[numerical_cog].mean().T.plot(kind='bar', color=['steelblue', 'salmon'])
plt.title('Cognitive Scores: Healthy vs Alzheimer')
plt.xticks(rotation=0)
plt.legend(['Healthy', 'Alzheimer'])
plt.tight_layout()
plt.show()

# %%
categorical_cog = ['MemoryComplaints', 'BehavioralProblems']

for col in categorical_cog:
    print(col)
    print(pd.crosstab(df[col], df['Diagnosis'], normalize='index'))
    print()
# Out:
# MemoryComplaints
# Diagnosis                0         1
# MemoryComplaints
# 0                 0.721504  0.278496
# 1                 0.360179  0.639821
#
# BehavioralProblems
# Diagnosis                  0         1
# BehavioralProblems
# 0                   0.692605  0.307395
# 1                   0.397626  0.602374

# %%
categorical_cog = ['MemoryComplaints', 'BehavioralProblems']
fig, axes = plt.subplots(3, 3, figsize=(15, 12))
axes = axes.flatten()

for i, col in enumerate(categorical_cog):
    crosstab = pd.crosstab(df[col], df['Diagnosis'], normalize='index')
    crosstab.plot(kind='bar', ax=axes[i], color=['steelblue', 'salmon'], legend=False)
    axes[i].set_title(col)
    axes[i].set_xlabel('')
    axes[i].set_xticklabels(['No', 'Yes'], rotation=0)

plt.suptitle('Cognitive Symptoms: Healthy vs Alzheimer', fontsize=14)
plt.tight_layout()
plt.show()

# %%
categorical_cog = ['Confusion', 'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks', 'Forgetfulness']

for col in categorical_cog:
    print(col)
    print(pd.crosstab(df[col], df['Diagnosis'], normalize='index'))
    print()
# Out:
# Confusion
# Diagnosis         0         1
# Confusion
# 0          0.641686  0.358314
# 1          0.664399  0.335601
#
# Disorientation
# Diagnosis              0         1
# Disorientation
# 0               0.641238  0.358762
# 1               0.673529  0.326471
#
# PersonalityChanges
# Diagnosis                  0         1
# PersonalityChanges
# 0                   0.642192  0.357808
# 1                   0.669753  0.330247
#
# DifficultyCompletingTasks
# Diagnosis                         0         1
# DifficultyCompletingTasks
# 0                          0.648230  0.351770
# 1                          0.636364  0.363636
#
# Forgetfulness
# Diagnosis             0         1
# Forgetfulness
# 0              0.646236  0.353764
# 1              0.646605  0.353395
